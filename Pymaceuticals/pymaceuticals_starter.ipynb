# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# The study conducted by Pymaceuticals focusing on evaluating the effectiveness of various treatment regimens, in treating SCC in mice. Over the course of the study:
#
# - 249 mice were treated with different drug regimens.
# - Tumor development was monitored over a 45-day period, and the goal was to compare the performance of Capomulin against other treatments.
# - The study involved generating multiple statistical analyses and visualizations such as summary statistics, bar charts, pie charts, box plots, and scatter plots.
# - The quartiles, outliers, and tumor volume distribution were calculated and visualized for treatment groups to assess effectiveness.
# - Capomulin was a key focus in the analysis as the company's drug of interest, with specific evaluation to determine its efficacy compared to other treatments.
#
# ## General Trends:
# - Capomulin and Ramicane seemed to be the most promising treatments in reducing tumor size. The overall tumor size across the study for these two drugs was lower compared to other treatments.
# - The drug showed less effectiveness with the increase of the mice weight.
# - Other drugs like Ceftamin and Infubinol did not perform as well, with tumor sizes.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
mouse_study = pd.merge(study_results, mouse_metadata, how="left", on="Mouse ID",)

# Display the data table for preview
mouse_study.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mouse_count = mouse_study["Mouse ID"].unique()
#To get the count of the unduplicated mice
mouse_count = len(mouse_count)
mouse_count
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
dup_mouse = mouse_study[mouse_study.duplicated(["Mouse ID", "Timepoint"], keep = False)]
#The unique method to return the unique mouse ID.
dup_mouse_id = dup_mouse["Mouse ID"].unique()
dup_mouse_id
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID.
dup_mouse
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 107   Female          21          26
# 137   Female          21          26
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_study = mouse_study[mouse_study["Mouse ID"]!="g989"]
clean_mouse_study.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
clean_mouse_count = clean_mouse_study["Mouse ID"].unique()
clean_mouse_count = len(clean_mouse_count)
clean_mouse_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume.
mean_tum_vol = clean_mouse_study.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].mean()
med_tum_vol = clean_mouse_study.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].median()
var_tum_vol = clean_mouse_study.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].var()
std_tum_vol = clean_mouse_study.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].std()
sem_tum_vol = clean_mouse_study.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary DataFrame.
summary_stats = pd.DataFrame({
    "Mean Tumor Volume": mean_tum_vol,
    "Median Tumor Volume": med_tum_vol,
    "Tumor Volume Variance": var_tum_vol,
    "Tumor Volume Std. Dev.": std_tum_vol,
    "Tumor Volume Std. Err.": sem_tum_vol
})

# Display the summary DataFrame
summary_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)


# Using the aggregation method, produce the same summary statistics in a single line
agg_summary = clean_mouse_study.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":["mean", "median", "var", "std", "sem"]})
# Display the aggregated DataFrame
agg_summary
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
drug_mouse = clean_mouse_study.groupby("Drug Regimen")["Mouse ID"].count().sort_values(ascending=False)
#Create the bar plot
drug_mouse.plot.bar()

# Set labels for the x-axis and y-axis
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")

# Set the limits of the x-axis to center the bars and provide some spacing
plt.xlim(-0.5, len(drug_mouse)-0.5)
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
drug_mouse = clean_mouse_study.groupby("Drug Regimen")["Mouse ID"].count().sort_values(ascending=False)

# Create a bar plot using pyplot
plt.bar(drug_mouse.index, drug_mouse.values)

# Set labels for the x-axis and y-axis
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")

# Rotate x-axis labels for better readability
plt.xticks(rotation=90, ha="right")

# Adjust x-axis limits for better alignment
plt.xlim(-0.5, len(drug_mouse) - 0.5)

# Show the plot
plt.tight_layout()  # Ensure everything fits without overlapping
plt.show()

# %%
# Generate a pie chart, using Pandas, showing the distribution of unique female versus male mice used in the study

# Grouping the mice count by sex
sex_count = clean_mouse_study.drop_duplicates(subset=["Mouse ID"]).groupby("Sex")["Mouse ID"].count()

# Define the colors for Female and Male
colors = ['orange', 'blue']

# Make the pie chart
sex_count.plot.pie(ylabel="Count",labels=["Female","Male"],autopct="%1.1f%%", colors=colors, startangle=180)

# Show the plot
plt.show()

# %%
# Generate a pie chart, using pyplot, showing the distribution of unique female versus male mice used in the study

# Get the unique mice with their gender
sex_count = clean_mouse_study.drop_duplicates(subset=["Mouse ID"]).groupby("Sex")["Mouse ID"].count()

# Define the colors for Female and Male
colors = ["orange", "blue"]

# Make the pie chart
sex_count.plot.pie(autopct="%1.1f%%",colors=colors,startangle=180,labels=["Female", "Male"],)

#Setting the y-axis to count
plt.ylabel("count")

# Show the plot
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin
four_drugs = clean_mouse_study.loc[(clean_mouse_study["Drug Regimen"] == "Capomulin") |
                                    (clean_mouse_study["Drug Regimen"] == "Ramicane") |
                                    (clean_mouse_study["Drug Regimen"] == "Infubinol") |
                                    (clean_mouse_study["Drug Regimen"] == "Ceftamin")]

# Start by getting the last (greatest) timepoint for each mouse
four_drugs = four_drugs.groupby(["Drug Regimen", "Mouse ID"])["Timepoint"].max().reset_index()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
four_drugs = pd.merge(four_drugs, clean_mouse_study[["Mouse ID", "Timepoint", "Tumor Volume (mm3)"]],
                     on=["Mouse ID", "Timepoint"], how="left")

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers.
for drug in treatments:

    # Locate the rows which contain mice on each drug and get the tumor volumes
    drug_data = four_drugs.loc[four_drugs["Drug Regimen"] == drug, "Tumor Volume (mm3)"]

    # add subset- add data to the list for plotting later
    tumor_vol_data.append(drug_data)

    # Calculate the quartiles and IQR
    quartiles = drug_data.quantile([0.25, 0.5, 0.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq
    
    # Reset the index of drug_data before checking for outliers
    drug_data = drug_data.reset_index(drop=True)

    # Determine outliers using upper and lower bounds
    lower_bound = lowerq - (1.5 * iqr)
    upper_bound = upperq + (1.5 * iqr)
    
     # Print outliers if they exist
    outliers = drug_data[(drug_data < lower_bound) | (drug_data > upper_bound)]
    print(f"{drug} potential outliers: {outliers}")
# Out:
# Capomulin potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol potential outliers: 5    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distribution of the tumor volume for each treatment group.
Capomulin = [] 
Ramicane = [] 
Infubinol = [] 
Ceftamin = []

for x in range(100):
            drug= four_drugs.iloc[x,:]["Drug Regimen"]
            tumor_valume= four_drugs.iloc[x,:]["Tumor Volume (mm3)"]
            if drug=="Capomulin":
                Capomulin.append(tumor_valume)
            if drug=="Ramicane":
                Ramicane.append(tumor_valume)
            if drug=="Infubinol":
                Infubinol.append(tumor_valume)
            if drug=="Ceftamin":
                Ceftamin.append(tumor_valume)    
                continue

data =pd.DataFrame({"Capomulin":Capomulin, "Ramicane": Ramicane, "Infubinol":Infubinol, "Ceftamin":Ceftamin})
ax = data[["Capomulin","Ramicane","Infubinol","Ceftamin"]].plot(kind="box")
# Set the y-axis label to "Final Tumor Volume (mm3)"
ax.set_ylabel("Final Tumor Volume (mm3)")

# Set the x-axis label to "Drug Regimen"
ax.set_xlabel("Drug Regimen")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
Capomulin = clean_mouse_study.loc[(clean_mouse_study["Drug Regimen"]=="Capomulin") & 
                                (clean_mouse_study["Mouse ID"]=="l509")][["Timepoint","Tumor Volume (mm3)"]]
# Create the plot using matplotlib directly
plt.plot(Capomulin["Timepoint"], Capomulin["Tumor Volume (mm3)"])

# Add the title and labels
plt.title("Capomulin treatment of mouse l509")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")

# Show the plot
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
# Filter data for the Capomulin regimen
capomulin_data = clean_mouse_study.loc[clean_mouse_study["Drug Regimen"] == "Capomulin"]

# Group by Mouse ID and calculate the average tumor volume for each mouse
capomulin_avg_tumor_vol = capomulin_data.groupby("Mouse ID")[["Tumor Volume (mm3)", "Weight (g)"]].mean()

# Reset the index to make "Mouse ID" a column
capomulin_avg_tumor_vol = capomulin_avg_tumor_vol.reset_index()

# Create a scatter plot using matplotlib
plt.scatter(capomulin_avg_tumor_vol["Weight (g)"], capomulin_avg_tumor_vol["Tumor Volume (mm3)"])

# Add X & Y labels
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")

# Show the plot
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
x_values = capomulin_avg_tumor_vol['Weight (g)']
y_values = capomulin_avg_tumor_vol["Tumor Volume (mm3)"]

# Calculating the Pearson correlation coefficient between x_values (mouse weight) and y_values (average tumor volume).
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}")

#Generating the linear in red and font size 15
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

# adding the X and Y labels
plt.xlabel("Weight of Mouse in g")
plt.ylabel("Average Tumor Volume(mm3)")
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
